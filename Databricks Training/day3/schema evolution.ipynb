# %%
data=([(1,'Virat'),(2,'Rohit')])
schema="id int, name string"

df=spark.createDataFrame(data,schema)
display(df)

# %%
df.write.mode("overwrite").saveAsTable("acc_dev.pranav.cricket")

# %%
# %sql
select * from acc_dev.pranav.cricket

# %%
data=([(3,'Sachin'),(4,'Dhoni')])
schema="id int, name string"

df=spark.createDataFrame(data,schema)
display(df)

# %%
df.write.mode("append").saveAsTable("acc_dev.pranav.cricket")

# %%
# %sql
select * from acc_dev.pranav.cricket

# %%
data=([(5,'sky','All Rounder'),(6,'Shubnam','Batsman')])
schema="id int, name string, role string"

df=spark.createDataFrame(data,schema)
display(df)

# %%
df.write.mode("append").option("mergeSchema", "true").saveAsTable("acc_dev.pranav.cricket")

# %%
df=spark.table("acc_dev.pranav.cricket")

# %%
# %sql
select * from acc_dev.pranav.cricket

# %%
data=([(7,'Bowler'),(8,'Batsman')])
schema="id int, role string"

df=spark.createDataFrame(data,schema)
display(df)

# %%
df.write.mode("append").option("mergeSchema", "true").saveAsTable("acc_dev.pranav.cricket")

# %%
# %sql 
Select * from acc_dev.pranav.cricket

# %%
# %sql
DESC History acc_dev.naval.cricket

# %%
# %sql
restore acc_dev.naval.cricket to version as of 2;

# %%
# %sql
Select * from acc_dev.naval.cricket
