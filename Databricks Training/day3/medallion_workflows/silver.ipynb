-- %%
%run "/Workspace/Users/polasaipranav@gmail.com/Databricks Training/day3/medallion_workflows/includes"

-- %%
%python
# reader
df=spark.table(f"{catalog}.{schema}.sales")

#transform
df1=df.dropDuplicates().dropna().drop("ingestion_date","path")

#write
df1.write.mode("overwrite").saveAsTable(f"{catalog}.pranav_02_silver.sales_cleaned")

-- %%
select * from acc_dev.pranav_02_silver.sales_cleaned
