-- %%
%sql
use catalog acc_dev;
use schema pranav

-- %%
%sql
create table if not exists emp(id int, name string, city string)

-- %%
%sql
insert into emp values (1,'Sai','Sangareddy')

-- %%
%sql
Select * from emp;

-- %%
%sql
DESC Extended emp;

-- %%
%sql 
DESC HISTORY emp

-- %%
 
DESC Extended emp

-- %%
DESC Detail emp;

-- %%
insert into emp values (2,'Pranav','ZHB'),(3,'Man','WGL');

-- %%
Select * from emp version as of 2

-- %%
Delete from emp
where id = 3;

-- %%
Select * from emp version as of 2

-- %%
insert into acc_dev.naval.emp values (2,'Pranav','Sangareddy')

-- %%
desc history acc_dev.naval.emp

-- %%
delete from emp;

-- %%
desc history emp

-- %%
restore emp to version as of  2
