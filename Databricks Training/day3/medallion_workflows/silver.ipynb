-- %%
%run "/Workspace/Users/polasaipranav@gmail.com/databricks-public/Databricks Training/day3/medallion_workflows/includes"

-- %%
%python
# reader
df=spark.table(f"{catalog}.{schema}.sales")

#transform
df1=df.dropDuplicates().dropna().drop("ingestion_date","path")

#write
df1.write.mode("overwrite").saveAsTable(f"{catalog}.bronze.sales_cleaned")

-- %%
select * from dev.bronze.sales_cleaned
