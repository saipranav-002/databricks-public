# %% [markdown]
# ##Step 1 : Reading Data

# %%
df=spark.read.csv("/Volumes/acc_dev/naval/raw/financial_dataset.csv",header=True,inferSchema=True)

# %% [markdown]
# ###Step 2 : Transforming Data

# %%
df.select("CustomerID","TransactionID")

# %%
df1=df.filter("CustomerID='CUST0007'")

# %%
df1.display()

# %% [markdown]
# Lazy Evaluation
#
# Transformations
# read
# select
# filter
# sort
# withColumnRenamed
# withColumn

# %%
from pyspark.sql.functions import *
df.select(col("CustomerID").alias("cust_id")).display()

# %%
df1=df.withColumnsRenamed({"CustomerID":"cust_id","TransactionID":"transaction_id"}).display()

# %%
df.withColumn("ingestion_date",current_timestamp()).display()
