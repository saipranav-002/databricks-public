# %%
data=([(1,'a'),(2,'b'),(3,'c')])
schema="id int, name string"
df=spark.createDataFrame(data,schema)

# %%
df.show()

# %%
data=([(1,'a',1),(2,'b',2)])
schema="id int, name string, order_id int"
_sqldf=spark.createDataFrame(data,schema)
_sqldf.show()

# %%
from datetime import datetime, date
import pandas as pd
from pyspark.sql import Row
from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

df = spark.createDataFrame([
    Row(a=1, b=2., c='string1', d=date(2000, 1, 1), e=datetime(2000, 1, 1, 12, 0)),
    Row(a=2, b=3., c='string2', d=date(2000, 2, 1), e=datetime(2000, 1, 2, 12, 0)),
    Row(a=4, b=5., c='string3', d=date(2000, 3, 1), e=datetime(2000, 1, 3, 12, 0))
])
df
df.show()

# %%
from datetime import datetime, date
import pandas as pd
from pyspark.sql import Row

df = spark.createDataFrame([
    Row(a=1, b=2., c='string1', d=date(2000, 1, 1), e=datetime(2000, 1, 1, 12, 0)),
    Row(a=2, b=3., c='string2', d=date(2000, 2, 1), e=datetime(2000, 1, 2, 12, 0)),
    Row(a=4, b=5., c='string3', d=date(2000, 3, 1), e=datetime(2000, 1, 3, 12, 0))
])
df.display()

# %% [markdown]
# ##Reader API

# %%
df_sales = spark.read.csv("/Volumes/acc_dev/naval/raw/csv/sales.csv")
df_sales.write.saveAsTable("acc_dev.pranav.sales_py")

# %%
(spark
 .read
 .csv("/Volumes/acc_dev/naval/raw/csv/sales.csv")
 .write
 .mode("overwrite")
 .saveAsTable("acc_dev.pranav.sales_py"))

# %% [markdown]
# ##Reading From a Parquet

# %%
df_house_pricing = spark.read.parquet("/Volumes/acc_dev/naval/raw/house-price.parquet")
df_house_pricing.show()

# %%
df_house_pricing.write.saveAsTable("acc_dev.pranav.house_pricing_py")

# %%
# %sql
Select * from acc_dev.pranav.house_pricing_py

# %%
df_house_pricing.write.mode("append").saveAsTable("acc_dev.pranav.house_pricing_py")

# %% [markdown]
# ##Reading JSON

# %%
df_json = spark.read.json("/Volumes/acc_dev/naval/raw/retail_orders.json")

# %%
df_json.show()

# %%
df_json.write.mode("overwrite").saveAsTable("acc_dev.pranav.retail_orders")

# %%
# %sql
select * from acc_dev.pranav.retail_orders

# %%
df = spark.read
