# %% [markdown]
# ##Databricks Notebook

# %%
print('hello')

# %%
for i in range(1, 12):
    print(i)

# %%
# %sql
Select "Running SQL on Spark"

# %% [markdown]
# Data Objects
#
# - Catalog
# - Schema
# - Tables, Views, Volumes, Functions

# %%
# %sql
use catalog acc_dev;
create schema pranav;

# %%
# %sql
use catalog acc_dev;
use schema pranav;
create table if not exists acc_dev.pranav.demo_table()

# %% [markdown]
# ![](/Volumes/acc_dev/naval/raw/object-model.png)
