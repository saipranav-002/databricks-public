# %%
# %sql
SELECT sum(quantity) AS total_quantity, min(order_date) AS earliest_order_date
FROM acc_dev.pranav.sales

# %%
# %sql
SELECT 
  count(order_id) AS order_id_not_null_count, 
  count(customer_id) AS customer_id_not_null_count, 
  count(transaction_id) AS transaction_id_not_null_count
FROM acc_dev.pranav.sales
