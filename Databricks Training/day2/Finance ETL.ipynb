# %% [markdown]
# ##Reading Data

# %%
# %run "/Workspace/Users/polasaipranav@gmail.com/Databricks Training/day2/ETL_Utility"

# %%
df_finance = spark.read.csv(input_path,inferSchema=True,header=True)

# %% [markdown]
# ##Transforming The Data
# ####i. Renaming the cols to lower case
# ####ii. Adding new column for auditing
# ####iii. Adding a column for path

# %%
new_col=['transaction_id',
 'customer_id',
 'account_type',
 'transaction_type',
 'amount_usd',
 'branch',
 'transaction_date']

# %%
df1=df_finance.toDF(*new_col).withColumn("ingestion_date", current_timestamp()).withColumn("path",col("_metadata.file_name"))

# %%
df1.write.mode("overwrite").saveAsTable("acc_dev.pranav.financials")

# %%
# %sql
Select * from acc_dev.pranav.financials
